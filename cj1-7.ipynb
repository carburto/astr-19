# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1, 100)


y = np.exp(x)

# %%
plt.plot(x, y, 'b-')


#axes labels
plt.xlabel('Time [milliseconds]')
plt.ylabel('Awesomeness')

plt.savefig("cj1-7.pdf",bbox_inches="tight", facecolor="white")
